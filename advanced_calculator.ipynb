# %% [markdown]
# <a href="https://colab.research.google.com/github/BatXprO/batxpro.githib.io/blob/main/advanced_calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Create a DataFrame to compare GUI libraries
data = {
    'Library': ['Tkinter', 'PyQt', 'Kivy'],
    'Ease of Use': ['High', 'Medium', 'Medium'],
    'Features': ['Basic', 'Rich', 'Modern/Mobile-focused'],
    'Licensing': ['BSD (included with Python)', 'GPL/Commercial', 'MIT'],
    'Community Support': ['High', 'High', 'Medium']
}
df_gui_comparison = pd.DataFrame(data)

# Display the comparison
display(df_gui_comparison)

# Justification for choosing Tkinter for a simple calculator
print("Based on the comparison, Tkinter is a good choice for a simple calculator because:")
print("- It is included with Python, meaning no extra installation is needed.")
print("- It is known for its ease of use, which is suitable for a straightforward application.")
print("- While its features are basic, they are sufficient for building a simple calculator interface.")
# Out:
#    Library Ease of Use               Features                   Licensing  \
# 0  Tkinter        High                  Basic  BSD (included with Python)
# 1     PyQt      Medium                   Rich              GPL/Commercial
# 2     Kivy      Medium  Modern/Mobile-focused                         MIT
#
#   Community Support
# 0              High
# 1              High
# 2            Medium
# Based on the comparison, Tkinter is a good choice for a simple calculator because:
# - It is included with Python, meaning no extra installation is needed.
# - It is known for its ease of use, which is suitable for a straightforward application.
# - While its features are basic, they are sufficient for building a simple calculator interface.

# %% [markdown]
# ## Design the layout
#
# ### Subtask:
# Plan the arrangement of buttons, display area, and other elements of the calculator.

# %% [markdown]
# **Reasoning**:
# Describe the visual layout of the calculator, including the position and relative size of the display area and the buttons, and consider the arrangement and spacing of the buttons.

# %%
print("Calculator Layout Plan:")
print("-----------------------")
print("\nVisual Layout:")
print("The calculator will have a rectangular shape. The top portion will be occupied by the display area, which will be a single line entry widget to show input and results. Below the display area will be a grid of buttons.")

print("\nDisplay Area:")
print("- Position: Top of the calculator window.")
print("- Relative Size: Should span the full width of the window and have a reasonable height to clearly show the numbers.")

print("\nButton Layout (Grid):")
print("- The buttons will be arranged in a grid layout.")
print("- There will likely be a 4x4 or 5x4 grid to accommodate numbers, operators, and other functions.")
print("- Numbers (0-9): Will occupy the majority of the grid space, typically in rows of three (7, 8, 9; 4, 5, 6; 1, 2, 3) with 0 and the decimal point below.")
print("- Operators (+, -, *, /): Will likely be placed in a column to the right of the number buttons.")
print("- Clear (C or AC): Will be placed in a prominent position, perhaps above the numbers or in the top row of buttons.")
print("- Equals (=): Will likely be in the bottom right corner, spanning multiple columns if needed.")
print("- Other potential buttons (e.g., decimal point '.'): Will be integrated into the number grid.")

print("\nSpacing:")
print("- There should be consistent padding around the display area and between the buttons to improve readability and prevent accidental presses.")
print("- The buttons should be sized similarly to maintain a clean and organized look.")
# Out:
# Calculator Layout Plan:
# -----------------------
#
# Visual Layout:
# The calculator will have a rectangular shape. The top portion will be occupied by the display area, which will be a single line entry widget to show input and results. Below the display area will be a grid of buttons.
#
# Display Area:
# - Position: Top of the calculator window.
# - Relative Size: Should span the full width of the window and have a reasonable height to clearly show the numbers.
#
# Button Layout (Grid):
# - The buttons will be arranged in a grid layout.
# - There will likely be a 4x4 or 5x4 grid to accommodate numbers, operators, and other functions.
# - Numbers (0-9): Will occupy the majority of the grid space, typically in rows of three (7, 8, 9; 4, 5, 6; 1, 2, 3) with 0 and the decimal point below.
# - Operators (+, -, *, /): Will likely be placed in a column to the right of the number buttons.
# ...

# %% [markdown]
# ## Implement the display
#
# ### Subtask:
# Create the display widget to show the input and output of calculations.

# %% [markdown]
# **Reasoning**:
# Create the main window and the display widget using tkinter and configure its appearance.

# %%
import tkinter as tk

root = tk.Tk()
root.title("Advanced Calculator")

display = tk.Entry(root, font=('Arial', 24), justify='right')
display.pack(expand=True, fill='both')

display.insert(0, '0')
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /tmp/ipython-input-1355265267.py in <cell line: 0>()
#       1 import tkinter as tk
#       2
# ----> 3 root = tk.Tk()
#       4 root.title("Advanced Calculator")
#       5
#
# /usr/lib/python3.12/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2347                 baseName = baseName + ext
#    2348         interactive = False
# -> 2349         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2350         if _debug:
#    2351             self.tk.settrace(_print_command)
#
# TclError: no display name and no $DISPLAY environment variable

# %% [markdown]
# ## Create the buttons
#
# ### Subtask:
# Design and implement buttons for numbers, operators, and other functions.

# %% [markdown]
# **Reasoning**:
# Define the button labels and create a frame to hold the buttons.

# %%
button_labels = [
    '7', '8', '9', '/',
    '4', '5', '6', '*',
    '1', '2', '3', '-',
    '0', '.', '=', '+'
]

button_frame = tk.Frame(root)
button_frame.pack(expand=True, fill='both')

# %% [markdown]
# **Reasoning**:
# Iterate through the button labels, create buttons, configure them, and place them in the grid layout within the button frame.

# %%
import tkinter as tk

root = tk.Tk()
root.title("Advanced Calculator")

display = tk.Entry(root, font=('Arial', 24), justify='right')
display.pack(expand=True, fill='both')
display.insert(0, '0')

def button_click(button_text):
    current_display = display.get()

    if button_text == 'C':
        display.delete(0, tk.END)
        display.insert(0, '0')
    elif button_text == '=':
        try:
            # Evaluate the expression
            result = str(eval(current_display))
            display.delete(0, tk.END)
            display.insert(0, result)
        except Exception:
            # Handle errors (e.g., invalid syntax, division by zero)
            display.delete(0, tk.END)
            display.insert(0, "Error")
    else:
        # If the current display is "Error", clear it before inserting the new button text
        if current_display == "Error":
            display.delete(0, tk.END)
            display.insert(0, button_text)
        # Handle initial '0' or standard input appending
        elif current_display == '0' and button_text not in '+-*/.':
            display.delete(0, tk.END)
            display.insert(0, button_text)
        else:
            display.insert(tk.END, button_text)


button_labels = [
    '7', '8', '9', '/',
    '4', '5', '6', '*',
    '1', '2', '3', '-',
    '0', '.', '=', '+'
]

button_frame = tk.Frame(root)
button_frame.pack(expand=True, fill='both')

buttons = []
row = 0
col = 0
for label in button_labels:
    button = tk.Button(button_frame, text=label, font=('Arial', 18), command=lambda text=label: button_click(text))
    button.grid(row=row, column=col, sticky='nsew', padx=5, pady=5)
    buttons.append(button)

    col += 1
    if col > 3:
        col = 0
        row += 1

# Configure button frame grid to expand buttons
for i in range(4):
    button_frame.grid_columnconfigure(i, weight=1)
    button_frame.grid_rowconfigure(i, weight=1)

# Add the 'C' button separately
clear_button = tk.Button(button_frame, text='C', font=('Arial', 18), command=lambda text='C': button_click(text))
clear_button.grid(row=row, column=col, sticky='nsew', padx=5, pady=5)
buttons.append(clear_button)

# Configure the last row's grid to expand the clear button
button_frame.grid_columnconfigure(col, weight=1)
button_frame.grid_rowconfigure(row, weight=1)

# The main event loop is commented out because it requires a GUI environment
# root.mainloop()

# %% [markdown]
# **Reasoning**:
# The previous code block failed because the `button_labels` list was not defined in the same cell. Regenerate the code block including the definition of `button_labels`.

# %%
button_labels = [
    '7', '8', '9', '/',
    '4', '5', '6', '*',
    '1', '2', '3', '-',
    '0', '.', '=', '+'
]

button_frame = tk.Frame(root)
button_frame.pack(expand=True, fill='both')

buttons = []
row = 0
col = 0
for label in button_labels:
    button = tk.Button(button_frame, text=label, font=('Arial', 18))
    button.grid(row=row, column=col, sticky='nsew', padx=5, pady=5)
    buttons.append(button)

    col += 1
    if col > 3:
        col = 0
        row += 1

# Configure button frame grid to expand buttons
for i in range(4):
    button_frame.grid_columnconfigure(i, weight=1)
    button_frame.grid_rowconfigure(i, weight=1)

# Add the 'C' button separately
clear_button = tk.Button(button_frame, text='C', font=('Arial', 18))
clear_button.grid(row=row, column=col, sticky='nsew', padx=5, pady=5)
buttons.append(clear_button)

# Configure the last row's grid to expand the clear button
button_frame.grid_columnconfigure(col, weight=1)
button_frame.grid_rowconfigure(row, weight=1)

# %% [markdown]
# **Reasoning**:
# The previous code block failed because the `tk` module was not imported in the same cell. Regenerate the code block including the necessary import.

# %%
import tkinter as tk

button_labels = [
    '7', '8', '9', '/',
    '4', '5', '6', '*',
    '1', '2', '3', '-',
    '0', '.', '=', '+'
]

button_frame = tk.Frame(root)
button_frame.pack(expand=True, fill='both')

buttons = []
row = 0
col = 0
for label in button_labels:
    button = tk.Button(button_frame, text=label, font=('Arial', 18))
    button.grid(row=row, column=col, sticky='nsew', padx=5, pady=5)
    buttons.append(button)

    col += 1
    if col > 3:
        col = 0
        row += 1

# Configure button frame grid to expand buttons
for i in range(4):
    button_frame.grid_columnconfigure(i, weight=1)
    button_frame.grid_rowconfigure(i, weight=1)

# Add the 'C' button separately
clear_button = tk.Button(button_frame, text='C', font=('Arial', 18))
clear_button.grid(row=row, column=col, sticky='nsew', padx=5, pady=5)
buttons.append(clear_button)

# Configure the last row's grid to expand the clear button
button_frame.grid_columnconfigure(col, weight=1)
button_frame.grid_rowconfigure(row, weight=1)

# %% [markdown]
# **Reasoning**:
# The previous code block failed because the `root` window was not defined in the same cell. Regenerate the code block including the necessary import and the definition of the root window.

# %%
import tkinter as tk

root = tk.Tk()
root.title("Advanced Calculator")

display = tk.Entry(root, font=('Arial', 24), justify='right')
display.pack(expand=True, fill='both')
display.insert(0, '0')

button_labels = [
    '7', '8', '9', '/',
    '4', '5', '6', '*',
    '1', '2', '3', '-',
    '0', '.', '=', '+'
]

button_frame = tk.Frame(root)
button_frame.pack(expand=True, fill='both')

buttons = []
row = 0
col = 0
for label in button_labels:
    button = tk.Button(button_frame, text=label, font=('Arial', 18))
    button.grid(row=row, column=col, sticky='nsew', padx=5, pady=5)
    buttons.append(button)

    col += 1
    if col > 3:
        col = 0
        row += 1

# Configure button frame grid to expand buttons
for i in range(4):
    button_frame.grid_columnconfigure(i, weight=1)
    button_frame.grid_rowconfigure(i, weight=1)

# Add the 'C' button separately
clear_button = tk.Button(button_frame, text='C', font=('Arial', 18))
clear_button.grid(row=row, column=col, sticky='nsew', padx=5, pady=5)
buttons.append(clear_button)

# Configure the last row's grid to expand the clear button
button_frame.grid_columnconfigure(col, weight=1)
button_frame.grid_rowconfigure(row, weight=1)

# %% [markdown]
# ## Handle button clicks
#
# ### Subtask:
# Write functions to process button clicks and update the display.

# %% [markdown]
# **Reasoning**:
# Define the button_click function to handle button presses and update the display, including handling the clear 'C' button and the equals '=' button.

# %%
def button_click(button_text):
    current_display = display.get()

    if button_text == 'C':
        display.delete(0, tk.END)
        display.insert(0, '0')
    elif button_text == '=':
        # This will be implemented in a later subtask
        pass
    else:
        if current_display == '0' and button_text not in '+-*/.':
            display.delete(0, tk.END)
            display.insert(0, button_text)
        else:
            display.insert(tk.END, button_text)

# Modify the button creation loop to assign the button_click function
for button in buttons:
    button.config(command=lambda text=button['text']: button_click(text))

# Modify the clear button to use the button_click function
clear_button.config(command=lambda text='C': button_click(text))

# %% [markdown]
# **Reasoning**:
# The previous code block failed because the `clear_button` variable was not defined in the same block. Need to include the button creation code along with the function definition and assignment.

# %%
import tkinter as tk

root = tk.Tk()
root.title("Advanced Calculator")

display = tk.Entry(root, font=('Arial', 24), justify='right')
display.pack(expand=True, fill='both')
display.insert(0, '0')

def button_click(button_text):
    current_display = display.get()

    if button_text == 'C':
        display.delete(0, tk.END)
        display.insert(0, '0')
    elif button_text == '=':
        # This will be implemented in a later subtask
        pass
    else:
        if current_display == '0' and button_text not in '+-*/.':
            display.delete(0, tk.END)
            display.insert(0, button_text)
        else:
            display.insert(tk.END, button_text)

button_labels = [
    '7', '8', '9', '/',
    '4', '5', '6', '*',
    '1', '2', '3', '-',
    '0', '.', '=', '+'
]

button_frame = tk.Frame(root)
button_frame.pack(expand=True, fill='both')

buttons = []
row = 0
col = 0
for label in button_labels:
    button = tk.Button(button_frame, text=label, font=('Arial', 18), command=lambda text=label: button_click(text))
    button.grid(row=row, column=col, sticky='nsew', padx=5, pady=5)
    buttons.append(button)

    col += 1
    if col > 3:
        col = 0
        row += 1

# Configure button frame grid to expand buttons
for i in range(4):
    button_frame.grid_columnconfigure(i, weight=1)
    button_frame.grid_rowconfigure(i, weight=1)

# Add the 'C' button separately
clear_button = tk.Button(button_frame, text='C', font=('Arial', 18), command=lambda text='C': button_click(text))
clear_button.grid(row=row, column=col, sticky='nsew', padx=5, pady=5)
buttons.append(clear_button)

# Configure the last row's grid to expand the clear button
button_frame.grid_columnconfigure(col, weight=1)
button_frame.grid_rowconfigure(row, weight=1)

# %% [markdown]
# ## Implement the calculation logic
#
# ### Subtask:
# Develop the logic to evaluate the mathematical expressions entered by the user.

# %% [markdown]
# **Reasoning**:
# Implement the logic for the '=' button in the button_click function to evaluate the expression and handle potential errors.

# %%
import tkinter as tk

root = tk.Tk()
root.title("Advanced Calculator")

display = tk.Entry(root, font=('Arial', 24), justify='right')
display.pack(expand=True, fill='both')
display.insert(0, '0')

def button_click(button_text):
    current_display = display.get()

    if button_text == 'C':
        display.delete(0, tk.END)
        display.insert(0, '0')
    elif button_text == '=':
        try:
            # Evaluate the expression
            result = str(eval(current_display))
            display.delete(0, tk.END)
            display.insert(0, result)
        except Exception as e:
            # Handle errors (e.g., invalid syntax, division by zero)
            display.delete(0, tk.END)
            display.insert(0, "Error")
            print(f"Error evaluating expression: {e}") # Optional: print error to console
    else:
        if current_display == '0' and button_text not in '+-*/.':
            display.delete(0, tk.END)
            display.insert(0, button_text)
        else:
            display.insert(tk.END, button_text)

button_labels = [
    '7', '8', '9', '/',
    '4', '5', '6', '*',
    '1', '2', '3', '-',
    '0', '.', '=', '+'
]

button_frame = tk.Frame(root)
button_frame.pack(expand=True, fill='both')

buttons = []
row = 0
col = 0
for label in button_labels:
    button = tk.Button(button_frame, text=label, font=('Arial', 18), command=lambda text=label: button_click(text))
    button.grid(row=row, column=col, sticky='nsew', padx=5, pady=5)
    buttons.append(button)

    col += 1
    if col > 3:
        col = 0
        row += 1

# Configure button frame grid to expand buttons
for i in range(4):
    button_frame.grid_columnconfigure(i, weight=1)
    button_frame.grid_rowconfigure(i, weight=1)

# Add the 'C' button separately
clear_button = tk.Button(button_frame, text='C', font=('Arial', 18), command=lambda text='C': button_click(text))
clear_button.grid(row=row, column=col, sticky='nsew', padx=5, pady=5)
buttons.append(clear_button)

# Configure the last row's grid to expand the clear button
button_frame.grid_columnconfigure(col, weight=1)
button_frame.grid_rowconfigure(row, weight=1)

# The main event loop will be started in a subsequent step if needed in a GUI environment
# root.mainloop()

# %% [markdown]
# ## Handle errors
#
# ### Subtask:
# Add error handling for invalid input or operations.

# %% [markdown]
# **Reasoning**:
# Review the existing code and ensure the error handling in the `button_click` function for the '=' button is robust. The current implementation uses a broad `except Exception`, which is a good starting point. I need to make sure that after an error, subsequent button clicks (except 'C') clear the "Error" message. I will modify the `button_click` function to handle this.

# %%
import tkinter as tk

root = tk.Tk()
root.title("Advanced Calculator")

display = tk.Entry(root, font=('Arial', 24), justify='right')
display.pack(expand=True, fill='both')
display.insert(0, '0')

def button_click(button_text):
    current_display = display.get()

    if button_text == 'C':
        display.delete(0, tk.END)
        display.insert(0, '0')
    elif button_text == '=':
        try:
            # Evaluate the expression
            result = str(eval(current_display))
            display.delete(0, tk.END)
            display.insert(0, result)
        except Exception:
            # Handle errors (e.g., invalid syntax, division by zero)
            display.delete(0, tk.END)
            display.insert(0, "Error")
    else:
        # If the current display is "Error", clear it before inserting the new button text
        if current_display == "Error":
            display.delete(0, tk.END)
            display.insert(0, button_text)
        # Handle initial '0' or standard input appending
        elif current_display == '0' and button_text not in '+-*/.':
            display.delete(0, tk.END)
            display.insert(0, button_text)
        else:
            display.insert(tk.END, button_text)


button_labels = [
    '7', '8', '9', '/',
    '4', '5', '6', '*',
    '1', '2', '3', '-',
    '0', '.', '=', '+'
]

button_frame = tk.Frame(root)
button_frame.pack(expand=True, fill='both')

buttons = []
row = 0
col = 0
for label in button_labels:
    button = tk.Button(button_frame, text=label, font=('Arial', 18), command=lambda text=label: button_click(text))
    button.grid(row=row, column=col, sticky='nsew', padx=5, pady=5)
    buttons.append(button)

    col += 1
    if col > 3:
        col = 0
        row += 1

# Configure button frame grid to expand buttons
for i in range(4):
    button_frame.grid_columnconfigure(i, weight=1)
    button_frame.grid_rowconfigure(i, weight=1)

# Add the 'C' button separately
clear_button = tk.Button(button_frame, text='C', font=('Arial', 18), command=lambda text='C': button_click(text))
clear_button.grid(row=row, column=col, sticky='nsew', padx=5, pady=5)
buttons.append(clear_button)

# Configure the last row's grid to expand the clear button
button_frame.grid_columnconfigure(col, weight=1)
button_frame.grid_rowconfigure(row, weight=1)

# The main event loop will be started in a subsequent step if needed in a GUI environment
# root.mainloop()

# %% [markdown]
# ## Run the application
#
# ### Subtask:
# Write the code to initialize and run the GUI application.

# %% [markdown]
# **Reasoning**:
# Call the mainloop() method on the root window object (root) to start the Tkinter event loop.

# %%
root.mainloop()

# %% [markdown]
# **Reasoning**:
# The variable `root` was not defined in the current kernel session. Re-run the previous code that defined `root` and then call `mainloop()` to start the GUI application.

# %%
import tkinter as tk

root = tk.Tk()
root.title("Advanced Calculator")

display = tk.Entry(root, font=('Arial', 24), justify='right')
display.pack(expand=True, fill='both')
display.insert(0, '0')

def button_click(button_text):
    current_display = display.get()

    if button_text == 'C':
        display.delete(0, tk.END)
        display.insert(0, '0')
    elif button_text == '=':
        try:
            # Evaluate the expression
            result = str(eval(current_display))
            display.delete(0, tk.END)
            display.insert(0, result)
        except Exception:
            # Handle errors (e.g., invalid syntax, division by zero)
            display.delete(0, tk.END)
            display.insert(0, "Error")
    else:
        # If the current display is "Error", clear it before inserting the new button text
        if current_display == "Error":
            display.delete(0, tk.END)
            display.insert(0, button_text)
        # Handle initial '0' or standard input appending
        elif current_display == '0' and button_text not in '+-*/.':
            display.delete(0, tk.END)
            display.insert(0, button_text)
        else:
            display.insert(tk.END, button_text)


button_labels = [
    '7', '8', '9', '/',
    '4', '5', '6', '*',
    '1', '2', '3', '-',
    '0', '.', '=', '+'
]

button_frame = tk.Frame(root)
button_frame.pack(expand=True, fill='both')

buttons = []
row = 0
col = 0
for label in button_labels:
    button = tk.Button(button_frame, text=label, font=('Arial', 18), command=lambda text=label: button_click(text))
    button.grid(row=row, column=col, sticky='nsew', padx=5, pady=5)
    buttons.append(button)

    col += 1
    if col > 3:
        col = 0
        row += 1

# Configure button frame grid to expand buttons
for i in range(4):
    button_frame.grid_columnconfigure(i, weight=1)
    button_frame.grid_rowconfigure(i, weight=1)

# Add the 'C' button separately
clear_button = tk.Button(button_frame, text='C', font=('Arial', 18), command=lambda text='C': button_click(text))
clear_button.grid(row=row, column=col, sticky='nsew', padx=5, pady=5)
buttons.append(clear_button)

# Configure the last row's grid to expand the clear button
button_frame.grid_columnconfigure(col, weight=1)
button_frame.grid_rowconfigure(row, weight=1)

root.mainloop()
